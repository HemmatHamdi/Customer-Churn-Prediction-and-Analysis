# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
# TODO: Define business objectives here.
# Example:
# business_objectives = {
#     "background": "Describe the organisational context and business area...",
#     "primary_objective": "What is the main business question or problem?",
#     "success_criteria": [
#         "Criterion 1: e.g., Reduce X by Y%",
#         "Criterion 2: e.g., Achieve Z accuracy"
#     ]
# }

business_objectives = {
    "background": "The dataset belongs to a telecommunications company that provides mobile services to customers. "
                  "The project focuses on analyzing customer behavior, usage patterns, and service-related factors "
                  "to understand customer retention and churn. The business area is customer relationship management "
                  "and retention strategy, where companies aim to maintain existing customers and reduce customer loss.",

    "primary_objective": "The primary objective of this project is to predict whether a customer is likely to churn "
                         "(leave the company) or remain. By identifying customers at  risk of leaving, the company "
                         "can take proactive actions such as offering promotions and improving service quality.",

    "success_criteria": [
        "Achieve high prediction accuracy (e.g., above 85–90%) in identifying churn customers",
        "Reduce customer churn rate (e.g., by 10–15%) through targeted retention strategies",
        "Increase customer lifetime value by retaining high-value customers"
    ]
}

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()
# Out:
# >> BACKGROUND:
#    The dataset belongs to a telecommunications company that provides mobile services to customers. The project focuses on analyzing customer behavior, usage patterns, and service-related factors to understand customer retention and churn. The business area is customer relationship management and retention strategy, where companies aim to maintain existing customers and reduce customer loss.
#
# >> PRIMARY OBJECTIVE:
#    The primary objective of this project is to predict whether a customer is likely to churn (leave the company) or remain. By identifying customers at  risk of leaving, the company can take proactive actions such as offering promotions and improving service quality.
#
# >> SUCCESS CRITERIA:
#    - Achieve high prediction accuracy (e.g., above 85–90%) in identifying churn customers
#    - Reduce customer churn rate (e.g., by 10–15%) through targeted retention strategies
#    - Increase customer lifetime value by retaining high-value customers

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %%
# TODO: Assess the current situation here.
# Document resources, requirements, assumptions, constraints, and risks.

situation_assessment = {
    "resources": {
        "personnel": [
            "Data Analyst",
            "Data Scientist",
            "Domain Expert (Telecom)",
            "Project Supervisor"
        ],
        "data_sources": [
            "Cell2Cell Train Dataset (CSV file)",
            "Cell2Cell Holdout Dataset (CSV file)"
        ],
        "computing": "Local machine (Laptop/PC) with sufficient RAM for data processing",
        "software": [
            "Python 3.x",
            "Jupyter Notebook",
            "pandas",
            "numpy",
            "matplotlib",
            "seaborn",
            "scikit-learn"
        ]
    },

    "requirements": [
        "The model should accurately predict customer churn",
        "Data must be cleaned and preprocessed before modeling",
        "The solution should be interpretable for business understanding",
        "The project should be completed within the given academic deadline"
    ],

    "assumptions": [
        "The dataset is representative of real telecom customer behavior",
        "The 'Churn' column correctly reflects customer decisions",
        "No major data leakage exists between train and holdout datasets",
        "Customer behavior patterns remain relatively stable over time"
    ],

    "constraints": [
        "Limited computational resources (no cloud computing)",
        "Time constraints due to assignment deadline",
        "Possible missing or noisy data in the dataset",
        "Limited domain knowledge about telecom industry"
    ],

    "risks_and_contingencies": [
        {
            "risk": "Poor data quality (missing or inconsistent values)",
            "probability": "High",
            "mitigation": "Apply data cleaning, imputation, and preprocessing techniques"
        },
        {
            "risk": "Model overfitting",
            "probability": "Medium",
            "mitigation": "Use cross-validation and regularization techniques"
        },
        {
            "risk": "Low prediction performance",
            "probability": "Medium",
            "mitigation": "Try multiple models and perform feature engineering"
        },
      
    ],

    "terminology": {
        "Churn": "When a customer stops using the company's service",
        "Feature": "An input variable used in the model",
        "Model": "A machine learning algorithm used to make predictions",
        "Recall": "The ability of the model to correctly identify churn customers",
        "Overfitting": "When a model performs well on training data but poorly on new data"
    },

    "cost_benefit": "The cost of implementing this solution is relatively low since it mainly requires data analysis and machine learning tools. "
                    "The benefit is significant, as predicting and reducing customer churn can save the company large amounts of revenue, "
                    "improve customer retention, and increase overall profitability."
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "resources": {
#     "personnel": [
#       "Data Analyst",
#       "Data Scientist",
#       "Domain Expert (Telecom)",
#       "Project Supervisor"
#     ],
#     "data_sources": [
#       "Cell2Cell Train Dataset (CSV file)",
#       "Cell2Cell Holdout Dataset (CSV file)"
#     ],
#     "computing": "Local machine (Laptop/PC) with sufficient RAM for data processing",
#     "software": [
#       "Python 3.x",
#       "Jupyter Notebook",
#       "pandas",
#       "numpy",
#       "matplotlib",
#       "seaborn",
#       "scikit-learn"
#     ]
#   },
#   "requirements": [
#     "The model should accurately predict customer churn",
#     "Data must be cleaned and preprocessed before modeling",
#     "The solution should be interpretable for business understanding",
#     "The project should be completed within the given academic deadline"
#   ],
#   "assumptions": [
#     "The dataset is representative of real telecom customer behavior",
#     "The 'Churn' column correctly reflects customer decisions",
#     "No major data leakage exists between train and holdout datasets",
#     "Customer behavior patterns remain relatively stable over time"
#   ],
#   "constraints": [
#     "Limited computational resources (no cloud computing)",
#     "Time constraints due to assignment deadline",
#     "Possible missing or noisy data in the dataset",
#     "Limited domain knowledge about telecom industry"
#   ],
#   "risks_and_contingencies": [
#     {
#       "risk": "Poor data quality (missing or inconsistent values)",
#       "probability": "High",
#       "mitigation": "Apply data cleaning, imputation, and preprocessing techniques"
#     },
#     {
#       "risk": "Model overfitting",
#       "probability": "Medium",
#       "mitigation": "Use cross-validation and regularization techniques"
#     },
#     {
#       "risk": "Low prediction performance",
#       "probability": "Medium",
#       "mitigation": "Try multiple models and perform feature engineering"
#     }
#   ],
#   "terminology": {
#     "Churn": "When a customer stops using the company's service",
#     "Feature": "An input variable used in the model",
#     "Model": "A machine learning algorithm used to make predictions",
#     "Recall": "The ability of the model to correctly identify churn customers",
#     "Overfitting": "When a model performs well on training data but poorly on new data"
#   },
#   "cost_benefit": "The cost of implementing this solution is relatively low since it mainly requires data analysis and machine learning tools. The benefit is significant, as predicting and reducing customer churn can save the company large amounts of revenue, improve customer retention, and increase overall profitability."
# }

# %%
# Optional: Add any further notes or elaboration on the situation assessment

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
# TODO: Define data mining goals here.

data_mining_goals = {
    "problem_type": "Binary Classification",

    "target_variable": "Churn",

    "technical_goals": [
        "Build a machine learning model to predict whether a customer will churn or not",
        "Identify the most important features that influence customer churn",
        "Perform feature engineering to improve model performance",
        "Handle class imbalance in the dataset to improve prediction of churn customers"
    ],

    "success_metrics": [
        "Accuracy >= 85%",
        "Recall (for churn class) >= 80%",
        "F1-Score >= 0.80",
        "AUC-ROC >= 0.85"
    ]
}
# Accuracy >= 85%: Overall correctness of predictions
# Recall >= 80%: Ability to detect churn customers (very important)
# F1-Score >= 0.80: Balance between precision and recall
# AUC-ROC >= 0.85: Model's ability to distinguish between churn and non-churn

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(f"  - {metric}")
# Out:
# ============================================================
# BUSINESS TO DATA MINING GOAL MAPPING
# ============================================================
#
# Business Objective : The primary objective of this project is to predict whether a customer is likely to churn (leave the company) or remain. By identifying customers at  risk of leaving, the company can take proactive actions such as offering promotions and improving service quality.
# Problem Type       : Binary Classification
# Target Variable    : Churn
#
# Technical Goals:
#   - Build a machine learning model to predict whether a customer will churn or not
#   - Identify the most important features that influence customer churn
#   - Perform feature engineering to improve model performance
#   - Handle class imbalance in the dataset to improve prediction of churn customers
#
# Success Metrics:
#   - Accuracy >= 85%
#   - Recall (for churn class) >= 80%
#   - F1-Score >= 0.80
#   - AUC-ROC >= 0.85

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
# TODO: Produce your project plan here.

project_plan = {
    "tools": [
        "pandas",
        "numpy",
        "matplotlib",
        "seaborn",
        "scikit-learn",
        "Jupyter Notebook"
    ],

    "techniques": [
        "Data Cleaning",
        "Exploratory Data Analysis (EDA)",
        "Feature Engineering",
        "Encoding Categorical Variables",
        "Handling Missing Values",
        "Feature Scaling",
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "Model Evaluation"
    ],

    "timeline": [
        {"phase": "Business Understanding", "duration": "Week 1", "status": "Completed"},
        {"phase": "Data Understanding", "duration": "Week 1", "status": "In Progress"},
        {"phase": "Data Preparation", "duration": "Week 2", "status": "Not Started"},
        {"phase": "Modelling", "duration": "Week 3", "status": "Not Started"},
        {"phase": "Evaluation", "duration": "Week 4", "status": "Not Started"},
        {"phase": "Deployment / Reporting", "duration": "Week 4", "status": "Not Started"}
    ],

    "dependencies": [
        "Business understanding must be completed before defining data mining goals.",
        "Data understanding must be completed before data preparation begins.",
        "Data preparation must be completed before modelling.",
        "Modelling must be completed before evaluation.",
        "Evaluation results are required before final reporting and deployment."
    ],

    "tool_justification": "Pandas and NumPy are used for data manipulation and preprocessing. "
                          "Matplotlib and Seaborn are used for visualization and exploratory data analysis. "
                          "Scikit-learn is used to build and evaluate machine learning models such as Logistic Regression, "
                          "Decision Tree, and Random Forest. Jupyter Notebook is used as the development environment "
                          "for running code, documenting analysis, and presenting results."
}

# %%
# Display the project plan
print("=" * 60)
print("PROJECT PLAN")
print("=" * 60)

print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nTimeline:")
if project_plan['timeline']:
    for phase in project_plan['timeline']:
        print(f"  [{phase.get('status', 'N/A'):^12}] {phase['phase']:<25} | {phase['duration']}")
else:
    print("  [Not yet defined]")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print(f"\nTool Justification: {project_plan['tool_justification']}")
# Out:
# ============================================================
# PROJECT PLAN
# ============================================================
#
# Tools: pandas, numpy, matplotlib, seaborn, scikit-learn, Jupyter Notebook
# Techniques: Data Cleaning, Exploratory Data Analysis (EDA), Feature Engineering, Encoding Categorical Variables, Handling Missing Values, Feature Scaling, Logistic Regression, Decision Tree, Random Forest, Model Evaluation
#
# Timeline:
#   [ Completed  ] Business Understanding    | Week 1
#   [In Progress ] Data Understanding        | Week 1
#   [Not Started ] Data Preparation          | Week 2
#   [Not Started ] Modelling                 | Week 3
#   [Not Started ] Evaluation                | Week 4
#   [Not Started ] Deployment / Reporting    | Week 4
#
# Dependencies:
#   - Business understanding must be completed before defining data mining goals.
#   - Data understanding must be completed before data preparation begins.
#   - Data preparation must be completed before modelling.
#   - Modelling must be completed before evaluation.
#   - Evaluation results are required before final reporting and deployment.
#
# Tool Justification: Pandas and NumPy are used for data manipulation and preprocessing. Matplotlib and Seaborn are used for visualization and exploratory data analysis. Scikit-learn is used to build and evaluate machine learning models such as Logistic Regression, Decision Tree, and Random Forest. Jupyter Notebook is used as the development environment for running code, documenting analysis, and presenting results.

# %%
# Optional: Summarise all Phase 1 outputs for reference in subsequent phases
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
# Out:
# ============================================================
# PHASE 1 SUMMARY: BUSINESS UNDERSTANDING
# ============================================================
#
# Primary Objective  : The primary objective of this project is to predict whether a customer is likely to churn (leave the company) or remain. By identifying customers at  risk of leaving, the company can take proactive actions such as offering promotions and improving service quality.
# Problem Type       : Binary Classification
# Target Variable    : Churn
# Tools Planned      : pandas, numpy, matplotlib, seaborn, scikit-learn, Jupyter Notebook
# Techniques Planned : Data Cleaning, Exploratory Data Analysis (EDA), Feature Engineering, Encoding Categorical Variables, Handling Missing Values, Feature Scaling, Logistic Regression, Decision Tree, Random Forest, Model Evaluation
